# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. Alessandro Gianola
#
#
# ### Grupo 25
# <dl>
#     <dt>20 horas (33.3%)</dt>
#     <dd>ist1106827 Cecília Correia</dd>
#     <dt>20 horas (33.3%)</dt>
#     <dd>ist105918 Gabriel Bispo</dd>
#     <dt>20 horas (33.3%)</dt>
#     <dd>ist106326 Guilherme Filipe</dd>
# <dl>

# %%
# %load_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://postgres:postgres@postgres/postgres
# Out:
# Deploy Dash apps for free on Ploomber Cloud! Learn more: https://ploomber.io/s/signup
# Connecting to 'postgresql+psycopg://postgres:***@postgres/postgres'

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
#
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns VARCHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# -- (RI-1)
# ALTER TABLE consulta ADD CONSTRAINT horario_consulta CHECK (
#   (hora >= '08:00:00' AND hora < '13:00:00' AND date_part('minute', hora) IN (0, 30)) OR
#   (hora >= '14:00:00' AND hora < '19:00:00' AND date_part('minute', hora) IN (0, 30))
# );
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# -- (RI-2)
# CREATE OR REPLACE FUNCTION check_doctor_patient() RETURNS TRIGGER AS
# $$
# BEGIN
#   IF NEW.ssn = (SELECT ssn FROM paciente WHERE nif = NEW.nif) THEN
#     RAISE EXCEPTION 'A doctor cannot consult themselves';
#   END IF;
#   RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE TRIGGER trg_check_doctor_patient
# BEFORE INSERT OR UPDATE ON consulta
# FOR EACH ROW EXECUTE FUNCTION check_doctor_patient();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# -- (RI-3)
# CREATE OR REPLACE FUNCTION check_doctor_clinic_day() RETURNS TRIGGER AS
# $$
# DECLARE
#   work_count INT;
# BEGIN
#   SELECT COUNT(*) INTO work_count
#   FROM trabalha
#   WHERE trabalha.nif = NEW.nif AND trabalha.nome = NEW.nome AND trabalha.dia_da_semana = EXTRACT(DOW FROM DATA(NEW.data));
#
#   IF work_count = 0 THEN
#     RAISE EXCEPTION 'Doctor cannot consult in a clinic where they do not work on the given day';
#   END IF;
#
#   RETURN NEW;
# END;
# $$ LANGUAGE plpgsql;
#
# CREATE TRIGGER trg_check_doctor_clinic_day
# BEFORE INSERT OR UPDATE ON consulta
# FOR EACH ROW EXECUTE FUNCTION check_doctor_clinic_day();
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta web/arquivos e a relação entre eles
# ...

# %% [markdown]
# ## 4. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano, mes e dia_do_mes: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# -- Drop the materialized view if it exists
# DROP MATERIALIZED VIEW IF EXISTS historial_paciente;
#
# -- Create the materialized view
# CREATE MATERIALIZED VIEW historial_paciente AS
# SELECT
#     c.id,
#     c.ssn,
#     c.nif,
#     c.nome,
#     c.data,
#     EXTRACT(YEAR FROM c.data) AS ano,
#     EXTRACT(MONTH FROM c.data) AS mes,
#     EXTRACT(DAY FROM c.data) AS dia_do_mes,
#     SUBSTRING(cl.morada FROM '.*\ ([^ ]+)$') AS localidade,
#     m.especialidade,
#     CASE
#         WHEN r.medicamento IS NOT NULL THEN 'receita'
#         WHEN o.parametro IS NOT NULL THEN 'observacao'
#
#     END AS tipo,
#     COALESCE(o.parametro, r.medicamento) AS chave,
#     COALESCE(o.valor, r.quantidade) AS valor
# FROM
#     consulta c
#     JOIN paciente p ON c.ssn = p.ssn
#     JOIN clinica cl ON c.nome = cl.nome
#     JOIN medico m ON c.nif = m.nif
#     LEFT JOIN observacao o ON c.id = o.id
#     LEFT JOIN receita r ON c.codigo_sns = r.codigo_sns;
# Out:
# 1283716 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP)
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# WITH observacoes_ortopedia AS (
#     SELECT
#         ssn,
#         data,
#         chave AS parametro
#     FROM historial_paciente
#     WHERE especialidade = 'ortopedia' AND tipo = 'observacao' AND valor IS NULL
# ),
# intervalos AS (
#     SELECT
#         ssn,
#         parametro,
#         data,
#         LAG(data) OVER (PARTITION BY ssn, parametro ORDER BY data) AS data_anterior
#     FROM observacoes_ortopedia
# ),
# diferencas AS (
#     SELECT
#         ssn,
#         parametro,
#         data - data_anterior AS intervalo
#     FROM intervalos
#     WHERE data_anterior IS NOT NULL
# )
# SELECT
#     ssn,
#     MAX(intervalo) AS max_intervalo
# FROM diferencas
# GROUP BY ssn
# ORDER BY max_intervalo DESC
# LIMIT 1;
# Out:
# 1 rows affected.
# +-------------+---------------+
# |     ssn     | max_intervalo |
# +-------------+---------------+
# | 53752978368 |      699      |
# +-------------+---------------+

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante os últimos doze meses, em consultas de cardiologia.

# %%
# %%sql
# SELECT
#     medicamento
# FROM (
#     SELECT
#         ssn,
#         chave AS medicamento,
#         COUNT(DISTINCT DATE_TRUNC('month', data)) AS meses_distintos
#     FROM historial_paciente
#     WHERE especialidade = 'cardiologia'
#         AND tipo = 'receita'
#         AND data >= (CURRENT_DATE - INTERVAL '1 year')
#     GROUP BY ssn, chave
# ) AS cardiologia_prescricoes
# WHERE meses_distintos = 12
# GROUP BY medicamento;
# Out:
# +-------------+
# | medicamento |
# +-------------+
# +-------------+

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# SELECT
#     hp.chave AS medicamento,
#     hp.localidade AS clinica_localidade,
#     hp.nome AS clinica_nome,
#     hp.mes AS mes,
#     hp.dia_do_mes AS dia_do_mes,
#     hp.especialidade AS especialidade,
#     m.nome AS medico_nome,
#     SUM(hp.valor) AS quantidade_total
# FROM historial_paciente AS hp
# JOIN medico AS m ON hp.nif = m.nif
# WHERE hp.tipo = 'receita' AND hp.ano = 2023
# GROUP BY GROUPING SETS(
#         (hp.chave),
#         (hp.chave, hp.localidade),
#         (hp.chave, hp.localidade, hp.nome),
#         (hp.chave, hp.mes),
#         (hp.chave, hp.mes, hp.dia_do_mes),
#         (hp.chave, hp.especialidade),
#         (hp.chave, hp.especialidade, m.nome)
#     )
# ORDER BY
#     medicamento,
#     clinica_localidade,
#     clinica_nome,
#     mes,
#     dia_do_mes,
#     especialidade,
#     medico_nome;
# Out:
# 31533 rows affected.
# +-------------+--------------------+--------------+------+------------+---------------+-------------+--------------------+
# | medicamento | clinica_localidade | clinica_nome | mes  | dia_do_mes | especialidade | medico_nome |  quantidade_total  |
# +-------------+--------------------+--------------+------+------------+---------------+-------------+--------------------+
# |  Metrica 1  |      Cascais       |  Clinica A   | None |    None    |      None     |     None    | 74410.29999999981  |
# |  Metrica 1  |      Cascais       |  Clinica C   | None |    None    |      None     |     None    | 73224.80000000002  |
# |  Metrica 1  |      Cascais       |  Clinica E   | None |    None    |      None     |     None    | 55635.800000000076 |
# |  Metrica 1  |      Cascais       |     None     | None |    None    |      None     |     None    | 203270.8999999988  |
# |  Metrica 1  |       Sintra       |  Clinica B   | None |    None    |      None     |     None    |  95341.9000000005  |
# |  Metrica 1  |       Sintra       |  Clinica D   | None |    None    |      None     |     None    | 73954.89999999976  |
# |  Metrica 1  |       Sintra       |     None     | None |    None    |      None     |     None    | 169296.80000000054 |
# |  Metrica 1  |        None        |     None     |  1   |     1      |      None     |     None    | 1343.3999999999996 |
# |  Metrica 1  |        None        |     None     |  1   |     2      |      None     |     None    | 870.2000000000003  |
# |  Metrica 1  |        None        |     None     |  1   |     3      |      None     |     None    |       527.5        |
# |  Metrica 1  |        None        |     None     |  1   |     4      |      None     |     None    |       403.6        |
# |  Metrica 1  |        None        |     None     |  1   |     5      |      None     |     None    | 1656.9999999999998 |
# |  Metrica 1  |        None        |     None     |  1   |     6      |      None     |     None    | 1377.8000000000002 |
# |  Metrica 1  |        None        |     None     |  1   |     7      |      None     |     None    | 952.5999999999999  |
# |  Metrica 1  |        None        |     None     |  1   |     8      |      None     |     None    | 1158.2000000000003 |
# |  Metrica 1  |        None        |     None     |  1   |     9      |      None     |     None    | 1203.1000000000001 |
# |  Metrica 1  |        None        |     None     |  1   |     10     |      None     |     None    | 937.1999999999999  |
# |  Metrica 1  |        None        |     None     |  1   |     11     |      None     |     None    | 914.3999999999999  |
# |  Metrica 1  |        None        |     None     |  1   |     12     |      None     |     None    | 559.8000000000001  |
# |  Metrica 1  |        None        |     None     |  1   |     13     |      None     |     None    |       939.8        |
# |  Metrica 1  |        None        |     None     |  1   |     14     |      None     |     None    | 816.2000000000003  |
# |  Metrica 1  |        None        |     None     |  1   |     15     |      None     |     None    | 1024.6000000000008 |
# |  Metrica 1  |        None        |     None     |  1   |     16     |      None     |     None    | 487.09999999999997 |
# |  Metrica 1  |        None        |     None     |  1   |     17     |      None     |     None    |       770.6        |
# |  Metrica 1  |        None        |     None     |  1   |     18     |      None     |     None    |       1439.9       |
# |  Metrica 1  |        None        |     None     |  1   |     19     |      None     |     None    |       1026.3       |
# |  Metrica 1  |        None        |     None     |  1   |     20     |      None     |     None    | 846.1999999999998  |
# |  Metrica 1  |        None        |     None     |  1   |     21     |      None     |     None    | 1511.5999999999992 |
# |  Metrica 1  |        None        |     None     |  1   |     22     |      None     |     None    | 1275.0000000000005 |
# |  Metrica 1  |        None        |     None     |  1   |     23     |      None     |     None    | 1038.8999999999999 |
# |  Metrica 1  |        None        |     None     |  1   |     24     |      None     |     None    |       2056.4       |
# |  Metrica 1  |        None        |     None     |  1   |     25     |      None     |     None    | 253.29999999999998 |
# |  Metrica 1  |        None        |     None     |  1   |     26     |      None     |     None    | 1186.5000000000002 |
# |  Metrica 1  |        None        |     None     |  1   |     27     |      None     |     None    |       800.6        |
# |  Metrica 1  |        None        |     None     |  1   |     28     |      None     |     None    |       1186.0       |
# |  Metrica 1  |        None        |     None     |  1   |     29     |      None     |     None    | 1322.7999999999997 |
# |  Metrica 1  |        None        |     None     |  1   |     30     |      None     |     None    | 968.0000000000002  |
# |  Metrica 1  |        None        |     None     |  1   |     31     |      None     |     None    | 1242.7000000000003 |
# |  Metrica 1  |        None        |     None     |  1   |    None    |      None     |     None    | 32097.300000000025 |
# |  Metrica 1  |        None        |     None     |  2   |     1      |      None     |     None    | 801.5999999999998  |
# |  Metrica 1  |        None        |     None     |  2   |     2      |      None     |     None    | 362.59999999999997 |
# |  Metrica 1  |        None        |     None     |  2   |     3      |      None     |     None    |       1037.5       |
# |  Metrica 1  |        None        |     None     |  2   |     4      |      None     |     None    | 1558.3000000000002 |
# |  Metrica 1  |        None        |     None     |  2   |     5      |      None     |     None    | 1293.4999999999995 |
# |  Metrica 1  |        None        |     None     |  2   |     6      |      None     |     None    | 738.4999999999999  |
# |  Metrica 1  |        None        |     None     |  2   |     7      |      None     |     None    | 990.4000000000001  |
# |  Metrica 1  |        None        |     None     |  2   |     8      |      None     |     None    | 497.20000000000005 |
# |  Metrica 1  |        None        |     None     |  2   |     9      |      None     |     None    | 1162.1999999999998 |
# |  Metrica 1  |        None        |     None     |  2   |     10     |      None     |     None    |       181.8        |
# |  Metrica 1  |        None        |     None     |  2   |     11     |      None     |     None    |       293.8        |
# |  Metrica 1  |        None        |     None     |  2   |     12     |      None     |     None    |       1102.8       |
# |  Metrica 1  |        None        |     None     |  2   |     13     |      None     |     None    |       1091.4       |
# |  Metrica 1  |        None        |     None     |  2   |     14     |      None     |     None    | 1902.7999999999997 |
# |  Metrica 1  |        None        |     None     |  2   |     15     |      None     |     None    | 1806.8999999999999 |
# |  Metrica 1  |        None        |     None     |  2   |     16     |      None     |     None    |       1264.5       |
# |  Metrica 1  |        None        |     None     |  2   |     17     |      None     |     None    |       154.8        |
# |  Metrica 1  |        None        |     None     |  2   |     18     |      None     |     None    | 935.2999999999997  |
# |  Metrica 1  |        None        |     None     |  2   |     19     |      None     |     None    |       604.1        |
# |  Metrica 1  |        None        |     None     |  2   |     20     |      None     |     None    |       1233.5       |
# |  Metrica 1  |        None        |     None     |  2   |     21     |      None     |     None    | 1851.8999999999983 |
# |  Metrica 1  |        None        |     None     |  2   |     22     |      None     |     None    | 457.9000000000001  |
# |  Metrica 1  |        None        |     None     |  2   |     23     |      None     |     None    | 822.0000000000001  |
# |  Metrica 1  |        None        |     None     |  2   |     24     |      None     |     None    |       1045.5       |
# |  Metrica 1  |        None        |     None     |  2   |     25     |      None     |     None    | 1137.0000000000007 |
# |  Metrica 1  |        None        |     None     |  2   |     26     |      None     |     None    | 792.6000000000003  |
# |  Metrica 1  |        None        |     None     |  2   |     27     |      None     |     None    | 1377.7000000000007 |
# |  Metrica 1  |        None        |     None     |  2   |     28     |      None     |     None    | 416.9999999999999  |
# |  Metrica 1  |        None        |     None     |  2   |    None    |      None     |     None    | 26915.100000000024 |
# |  Metrica 1  |        None        |     None     |  3   |     1      |      None     |     None    |       835.0        |
# |  Metrica 1  |        None        |     None     |  3   |     2      |      None     |     None    | 1388.199999999999  |
# |  Metrica 1  |        None        |     None     |  3   |     3      |      None     |     None    | 405.30000000000007 |
# |  Metrica 1  |        None        |     None     |  3   |     4      |      None     |     None    |       1178.1       |
# |  Metrica 1  |        None        |     None     |  3   |     5      |      None     |     None    | 1581.5999999999995 |
# |  Metrica 1  |        None        |     None     |  3   |     6      |      None     |     None    | 1380.400000000001  |
# |  Metrica 1  |        None        |     None     |  3   |     7      |      None     |     None    | 855.2999999999995  |
# |  Metrica 1  |        None        |     None     |  3   |     8      |      None     |     None    |       872.9        |
# |  Metrica 1  |        None        |     None     |  3   |     9      |      None     |     None    | 635.1999999999998  |
# |  Metrica 1  |        None        |     None     |  3   |     10     |      None     |     None    | 1146.3000000000004 |
# |  Metrica 1  |        None        |     None     |  3   |     11     |      None     |     None    | 851.8000000000001  |
# |  Metrica 1  |        None        |     None     |  3   |     12     |      None     |     None    | 1562.8999999999996 |
# |  Metrica 1  |        None        |     None     |  3   |     13     |      None     |     None    | 656.0999999999998  |
# |  Metrica 1  |        None        |     None     |  3   |     14     |      None     |     None    | 1395.1999999999996 |
# |  Metrica 1  |        None        |     None     |  3   |     15     |      None     |     None    | 1209.7999999999995 |
# |  Metrica 1  |        None        |     None     |  3   |     16     |      None     |     None    | 689.6999999999999  |
# |  Metrica 1  |        None        |     None     |  3   |     17     |      None     |     None    | 1014.4999999999998 |
# |  Metrica 1  |        None        |     None     |  3   |     18     |      None     |     None    |       1085.8       |
# |  Metrica 1  |        None        |     None     |  3   |     19     |      None     |     None    | 1055.3000000000002 |
# |  Metrica 1  |        None        |     None     |  3   |     20     |      None     |     None    | 1112.1999999999998 |
# |  Metrica 1  |        None        |     None     |  3   |     21     |      None     |     None    |       1200.9       |
# |  Metrica 1  |        None        |     None     |  3   |     22     |      None     |     None    | 1294.7000000000007 |
# |  Metrica 1  |        None        |     None     |  3   |     23     |      None     |     None    | 1355.5999999999997 |
# |  Metrica 1  |        None        |     None     |  3   |     24     |      None     |     None    |       334.7        |
# |  Metrica 1  |        None        |     None     |  3   |     25     |      None     |     None    | 965.5999999999999  |
# |  Metrica 1  |        None        |     None     |  3   |     26     |      None     |     None    |       797.0        |
# |  Metrica 1  |        None        |     None     |  3   |     27     |      None     |     None    | 688.8999999999999  |
# |  Metrica 1  |        None        |     None     |  3   |     28     |      None     |     None    |       787.0        |
# |  Metrica 1  |        None        |     None     |  3   |     29     |      None     |     None    |       1132.2       |
# |  Metrica 1  |        None        |     None     |  3   |     30     |      None     |     None    | 801.3000000000002  |
# |  Metrica 1  |        None        |     None     |  3   |     31     |      None     |     None    | 487.70000000000005 |
# |  Metrica 1  |        None        |     None     |  3   |    None    |      None     |     None    | 30757.200000000033 |
# +-------------+--------------------+--------------+------+------------+---------------+-------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# -- média (AVG) desvio padrão (STDDEV)
# WITH observacoes_metricas AS (
#     SELECT
#         hp.chave AS parametro,
#         hp.valor,
#         hp.nome AS clinica_nome,
#         hp.especialidade,
#         m.nome AS medico_nome
#     FROM historial_paciente AS hp
#     JOIN medico AS m ON hp.nif = m.nif
#     WHERE tipo = 'observacao' AND valor IS NOT NULL
# )
# SELECT
#     parametro,
#     clinica_nome,
#     especialidade,
#     medico_nome,
#     AVG(valor) AS valor_medio,
#     STDDEV(valor) AS desvio_padrao
# FROM observacoes_metricas
# GROUP BY
#     parametro,
#     clinica_nome,
#     especialidade,
#     medico_nome
# ORDER BY
#     parametro,
#     clinica_nome,
#     especialidade,
#     medico_nome;
# Out:
# 2380 rows affected.
# +-----------+--------------+----------------+------------------+--------------------+--------------------+
# | parametro | clinica_nome | especialidade  |   medico_nome    |    valor_medio     |   desvio_padrao    |
# +-----------+--------------+----------------+------------------+--------------------+--------------------+
# | Metrica 1 |  Clinica A   |  cardiologia   |  Carlos Pereira  |       37.64        | 1.5773395322504307 |
# | Metrica 1 |  Clinica A   |  cardiologia   |    Joao Costa    | 37.675000000000004 | 1.433028760552778  |
# | Metrica 1 |  Clinica A   |  cardiologia   |    Jose Costa    |      36.9875       | 1.3884643795695077 |
# | Metrica 1 |  Clinica A   |  cardiologia   |  Maria Pereira   | 37.57142857142857  | 1.3019765194283845 |
# | Metrica 1 |  Clinica A   |  cardiologia   |  Pedro Ferreira  | 37.60909090909092  | 1.3758303278053925 |
# | Metrica 1 |  Clinica A   |  dermatologia  |    Ana Sousa     |       37.425       | 1.7750251507272443 |
# | Metrica 1 |  Clinica A   |  dermatologia  |  Pedro Oliveira  | 37.516666666666666 | 1.7627685444142893 |
# | Metrica 1 |  Clinica A   |  dermatologia  |   Rita Martins   | 37.94444444444444  | 1.2471077651020288 |
# | Metrica 1 |  Clinica A   | medicina geral |    Joao Silva    | 37.900000000000006 | 1.4954096428738177 |
# | Metrica 1 |  Clinica A   | medicina geral |  Maria Ferreira  | 38.64444444444445  | 0.7923242882669803 |
# | Metrica 1 |  Clinica A   | medicina geral |  Paula Ferreira  | 37.43846153846153  | 1.588782794856104  |
# | Metrica 1 |  Clinica A   | medicina geral |  Sara Ferreira   | 37.17272727272727  | 1.099173243024874  |
# | Metrica 1 |  Clinica A   |   neurologia   |  Joao Rodrigues  | 38.25555555555556  | 1.3144496102086884 |
# | Metrica 1 |  Clinica A   |   neurologia   |    Rita Costa    | 37.20555555555555  | 1.5058600131104363 |
# | Metrica 1 |  Clinica A   |   ortopedia    |  Ana Goncalves   | 37.37500000000001  | 1.3649272199606386 |
# | Metrica 1 |  Clinica A   |   ortopedia    | Paula Rodrigues  | 37.221428571428575 | 1.6789092482133345 |
# | Metrica 1 |  Clinica A   |   ortopedia    |   Paula Silva    | 37.75333333333333  | 1.3736638529685403 |
# | Metrica 1 |  Clinica A   |   pediatria    | Carlos Goncalves |       37.39        | 1.1347540115226162 |
# | Metrica 1 |  Clinica A   |   pediatria    | Carlos Rodrigues | 38.17777777777778  | 1.2507775359529139 |
# | Metrica 1 |  Clinica A   |   pediatria    |  Joao Goncalves  |       37.54        | 1.5392638933377636 |
# | Metrica 1 |  Clinica A   |   pediatria    | Paula Goncalves  | 37.31578947368421  | 1.5617878494051978 |
# | Metrica 1 |  Clinica A   |   pediatria    |  Paula Oliveira  | 37.29090909090909  | 1.3902910094325893 |
# | Metrica 1 |  Clinica A   |   pediatria    |  Sara Rodrigues  | 36.82857142857143  | 1.2175306782093624 |
# | Metrica 1 |  Clinica B   |  cardiologia   |   Paula Sousa    | 38.339999999999996 | 0.7893034904268444 |
# | Metrica 1 |  Clinica B   |  dermatologia  |    Ana Sousa     |       37.55        | 0.9095175766428177 |
# | Metrica 1 |  Clinica B   |  dermatologia  | Carlos Ferreira  | 37.36363636363637  | 1.1629898772325789 |
# | Metrica 1 |  Clinica B   |  dermatologia  |   Jose Santos    |       37.075       | 1.3625081913253096 |
# | Metrica 1 |  Clinica B   |  dermatologia  |   Rita Martins   | 37.35333333333334  | 1.6387567877887805 |
# | Metrica 1 |  Clinica B   | medicina geral |  Ana Rodrigues   |        37.6        | 1.630950643030008  |
# | Metrica 1 |  Clinica B   | medicina geral |    Joao Sousa    | 37.66428571428571  | 1.7167084528503682 |
# | Metrica 1 |  Clinica B   | medicina geral |  Jose Rodrigues  |  36.6888888888889  | 1.4321700705960556 |
# | Metrica 1 |  Clinica B   | medicina geral | Maria Goncalves  | 36.93636363636364  | 1.118277896833097  |
# | Metrica 1 |  Clinica B   | medicina geral |  Maria Martins   | 37.32000000000001  | 1.5221695043588301 |
# | Metrica 1 |  Clinica B   | medicina geral |  Paula Ferreira  | 37.85833333333333  | 1.0858246412359367 |
# | Metrica 1 |  Clinica B   | medicina geral |   Paula Santos   |        37.5        | 1.5272524349301244 |
# | Metrica 1 |  Clinica B   | medicina geral |  Pedro Martins   |       36.95        | 1.590025728779825  |
# | Metrica 1 |  Clinica B   | medicina geral |   Pedro Silva    | 36.74444444444444  | 1.3463943619080465 |
# | Metrica 1 |  Clinica B   | medicina geral |   Pedro Sousa    |        37.5        | 1.7320508075688752 |
# | Metrica 1 |  Clinica B   | medicina geral |    Rita Sousa    | 37.212500000000006 | 1.305309669516526  |
# | Metrica 1 |  Clinica B   | medicina geral |  Sara Oliveira   | 37.57857142857143  | 1.3929374448534044 |
# | Metrica 1 |  Clinica B   |   neurologia   |   Carlos Costa   |       36.575       | 1.840968947773609  |
# | Metrica 1 |  Clinica B   |   neurologia   |  Joao Rodrigues  | 37.44666666666667  | 1.7332325978053957 |
# | Metrica 1 |  Clinica B   |   neurologia   |   Maria Costa    |       37.775       | 1.3423859355639858 |
# | Metrica 1 |  Clinica B   |   neurologia   |   Maria Silva    | 37.55999999999999  | 1.4515891674682306 |
# | Metrica 1 |  Clinica B   |   neurologia   | Pedro Rodrigues  | 38.074999999999996 | 1.5250186287982868 |
# | Metrica 1 |  Clinica B   |   neurologia   |    Rita Costa    |      37.7375       | 1.5004166088123667 |
# | Metrica 1 |  Clinica B   |   neurologia   |  Rita Rodrigues  |  37.8111111111111  | 1.595172455692077  |
# | Metrica 1 |  Clinica B   |   ortopedia    |  Ana Goncalves   | 37.62500000000001  | 1.4270917661772535 |
# | Metrica 1 |  Clinica B   |   ortopedia    |   Ana Oliveira   | 38.150000000000006 | 1.105893304075941  |
# | Metrica 1 |  Clinica B   |   ortopedia    |   Ana Pereira    |      37.39375      | 1.5264201038158973 |
# | Metrica 1 |  Clinica B   |   ortopedia    |    Ana Santos    |       37.95        | 0.3535533905932738 |
# | Metrica 1 |  Clinica B   |   pediatria    | Carlos Goncalves | 37.46666666666667  | 1.5340577998671796 |
# | Metrica 1 |  Clinica B   |   pediatria    |   Pedro Costa    |       37.45        | 2.263478149515329  |
# | Metrica 1 |  Clinica B   |   pediatria    |  Sara Rodrigues  | 37.32941176470588  | 1.366457420614684  |
# | Metrica 1 |  Clinica C   |  cardiologia   |   Joao Martins   | 37.400000000000006 | 1.6309506430300114 |
# | Metrica 1 |  Clinica C   |  cardiologia   |    Jose Costa    |        37.6        | 2.306512518934156  |
# | Metrica 1 |  Clinica C   |  cardiologia   |  Maria Pereira   | 37.083333333333336 | 1.4824529222429517 |
# | Metrica 1 |  Clinica C   |  dermatologia  |   Miguel Sousa   | 37.23076923076923  | 1.7006785975920597 |
# | Metrica 1 |  Clinica C   |  dermatologia  |   Sara Martins   | 37.685714285714276 | 1.3949674067640654 |
# | Metrica 1 |  Clinica C   | medicina geral |  Ana Rodrigues   | 36.63333333333333  | 1.5121728296285013 |
# | Metrica 1 |  Clinica C   | medicina geral |   Joao Santos    | 37.224999999999994 | 1.5341354009902206 |
# | Metrica 1 |  Clinica C   | medicina geral |  Jose Rodrigues  |      37.0375       | 1.1915625995185628 |
# | Metrica 1 |  Clinica C   | medicina geral |  Maria Martins   |       37.68        | 1.2443650768341432 |
# | Metrica 1 |  Clinica C   | medicina geral |   Miguel Costa   | 38.11538461538461  | 1.3384357498252448 |
# | Metrica 1 |  Clinica C   | medicina geral |   Paula Santos   | 36.925000000000004 | 1.4280356138016006 |
# | Metrica 1 |  Clinica C   | medicina geral |  Rita Goncalves  | 37.43333333333334  | 1.2659647177811366 |
# | Metrica 1 |  Clinica C   | medicina geral |  Sara Ferreira   | 38.37142857142857  | 1.0980502200328937 |
# | Metrica 1 |  Clinica C   |   neurologia   |    Ana Costa     |       37.17        | 1.5520953578952545 |
# | Metrica 1 |  Clinica C   |   ortopedia    |   Ana Oliveira   |      38.2875       | 1.173527446064501  |
# | Metrica 1 |  Clinica C   |   ortopedia    |   Ana Pereira    |       37.53        | 0.985506074168104  |
# | Metrica 1 |  Clinica C   |   ortopedia    |    Ana Santos    | 37.67692307692308  | 1.276027489455519  |
# | Metrica 1 |  Clinica C   |   ortopedia    |    Jose Silva    |     37.453125      | 1.4217173565570205 |
# | Metrica 1 |  Clinica C   |   ortopedia    |  Paula Pereira   | 37.182352941176475 | 1.4103347537542514 |
# | Metrica 1 |  Clinica C   |   ortopedia    | Paula Rodrigues  | 37.34000000000001  | 1.4039739517323195 |
# | Metrica 1 |  Clinica C   |   pediatria    |  Joao Goncalves  |       37.625       | 1.4155789050291878 |
# | Metrica 1 |  Clinica C   |   pediatria    |  Paula Oliveira  |      37.0375       | 1.4885675440951063 |
# | Metrica 1 |  Clinica C   |   pediatria    |    Sara Sousa    | 37.675000000000004 | 1.7078029479687962 |
# | Metrica 1 |  Clinica D   |  cardiologia   |    Joao Costa    | 38.114285714285714 | 1.279938185320591  |
# | Metrica 1 |  Clinica D   |  cardiologia   |   Joao Martins   |       36.92        | 1.3717449509753294 |
# | Metrica 1 |  Clinica D   |  cardiologia   | Maria Rodrigues  | 37.922222222222224 | 1.2577537296483943 |
# | Metrica 1 |  Clinica D   |  cardiologia   |   Paula Sousa    | 37.95384615384616  | 1.5365629310332978 |
# | Metrica 1 |  Clinica D   |  dermatologia  | Carlos Ferreira  |        37.8        | 1.5925965077079733 |
# | Metrica 1 |  Clinica D   |  dermatologia  |   Jose Santos    | 37.735294117647065 | 1.3481196054461333 |
# | Metrica 1 |  Clinica D   |  dermatologia  |   Paula Costa    |        36.1        |        None        |
# | Metrica 1 |  Clinica D   |  dermatologia  |  Pedro Oliveira  | 37.03636363636363  | 1.0688991788496496 |
# | Metrica 1 |  Clinica D   |  dermatologia  |   Sara Martins   | 37.800000000000004 | 1.4202112518917738 |
# | Metrica 1 |  Clinica D   | medicina geral |   Ana Martins    | 37.388888888888886 | 1.3944802484792287 |
# | Metrica 1 |  Clinica D   | medicina geral |   Joao Santos    | 36.95333333333334  | 1.215299296861637  |
# | Metrica 1 |  Clinica D   | medicina geral |    Joao Silva    | 37.199999999999996 | 1.5011106998930277 |
# | Metrica 1 |  Clinica D   | medicina geral |  Maria Ferreira  | 37.36666666666666  | 1.4927274681326281 |
# | Metrica 1 |  Clinica D   | medicina geral | Maria Goncalves  | 37.60555555555556  | 1.5268083674284971 |
# | Metrica 1 |  Clinica D   | medicina geral |   Pedro Sousa    | 37.82142857142856  | 1.2210831077547346 |
# | Metrica 1 |  Clinica D   | medicina geral |  Rita Goncalves  | 37.31666666666667  | 1.3670361658668269 |
# | Metrica 1 |  Clinica D   | medicina geral |  Sara Oliveira   | 36.93529411764706  | 1.3448704289217739 |
# | Metrica 1 |  Clinica D   | medicina geral |   Sara Pereira   | 38.455555555555556 | 1.1716559980547951 |
# | Metrica 1 |  Clinica D   |   neurologia   |   Maria Silva    | 38.074999999999996 | 1.6663105680187318 |
# | Metrica 1 |  Clinica D   |   ortopedia    |  Paula Pereira   |       37.21        | 1.7940952532621475 |
# | Metrica 1 |  Clinica D   |   pediatria    | Carlos Rodrigues | 37.07142857142857  | 1.2470536705141675 |
# | Metrica 1 |  Clinica D   |   pediatria    |   Pedro Costa    |       37.675       | 1.4353491814632648 |
# | Metrica 1 |  Clinica D   |   pediatria    |    Sara Sousa    | 36.416666666666664 | 1.1513759884011245 |
# +-----------+--------------+----------------+------------------+--------------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# SELECT nome
# FROM paciente
# JOIN consulta USING (ssn)
# JOIN observacao USING (id)
# WHERE parametro = ‘pressão diastólica’
# AND valor >= 9;

# %%
# %%sql
# CREATE INDEX IF NOT EXISTS idx_paciente_ssn ON paciente (ssn);
#
# CREATE INDEX IF NOT EXISTS idx_consulta_id ON consulta (id);
#
# CREATE INDEX IF NOT EXISTS idx_observacao_parametro ON observacao (parametro);
#
# CREATE INDEX IF NOT EXISTS idx_observacao_valor ON observacao (valor);
#
# CREATE INDEX IF NOT EXISTS idx_observacao_parametro_valor ON observacao (parametro, valor);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
# - idx_paciente_ssn: Melhora a performance da junção entre paciente e consulta utilizando ssn.
# - idx_consulta_id: Melhora a performance da junção entre consulta e observacao utilizando id.
# - idx_observacao_parametro: Acelera a busca de registros na tabela observacao que possuem o parametro.
# - idx_observacao_valor: Acelera a busca de registros na tabela observacao que possuem o valor maior ou igual a 9.
# - idx_observacao_parametro_valor: Um índice composto (parametro, valor) pode ser ainda mais eficiente para a condição WHERE que envolve ambos os atributos, permitindo que o banco de dados otimize a busca considerando as duas condições de uma só vez.

# %% [markdown]
# ### 6.2
# SELECT especialidade, SUM(quantidade) AS qtd
# FROM medico
# JOIN consulta USING (nif)
# JOIN receita USING (codigo_ssn)
# WHERE data BETWEEN ‘2023-01-01’ AND ‘2023-12-31’
# GROUP BY especialidade
# ORDER BY qtd;

# %%
# %%sql
# CREATE INDEX IF NOT EXISTS idx_medico_nif ON medico(nif);
#
# CREATE INDEX IF NOT EXISTS idx_consulta_nif ON consulta(nif);
#
# CREATE INDEX IF NOT EXISTS idx_consulta_codigo_sns ON consulta(codigo_sns);
#
# CREATE INDEX IF NOT EXISTS idx_receita_codigo_sns ON receita(codigo_sns);
#
# CREATE INDEX IF NOT EXISTS idx_consulta_data ON consulta(codigo_sns, nif, data);
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Justificação
#
# - idx_medico_nif, idx_consulta_nif, idx_consulta_codigo_sns, idx_receita_codigo_sns: Melhora a performance do JOIN statement.
# - idx_consulta_data: Melhora (codigo_sns, nif, data) é um 3 em 1.
# - Para o SUM, não é justificado um index.
